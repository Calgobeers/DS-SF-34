# %% [markdown]
# # DS-SF-34 | 05 | _k_-Nearest Neighbors | Codealong | Starter Code

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import preprocessing, neighbors, model_selection

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-05-iris.csv'))

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Part A | Activity | Iris Dataset | Exploratory Data Analysis

# %%
color = df.Species.map({'Setosa': 'red', 'Versicolor': 'green', 'Virginica': 'blue'})

# %%
df.plot(kind ='scatter', x  = 'SepalLength', y = 'SepalWidth', c= color )

# %%
pd.tools.plotting.scatter_matrix(df[ ['SepalLength','SepalWidth','PetalLength','PetalWidth']], c = color, figsize = (12, 12) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1197bd3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cdff5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cf657d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cfd7350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d05c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d09cb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d113d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1858d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d209d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d223250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d302c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d389c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d3faa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d480a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4f2350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d579490>]], dtype=object)

# %%
df.plot(kind = 'box')

# %%
df.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# ## Part B | Activity | Hand-Coded Classifier

# %%
c = df.Species

# %%
def my_first_classifier(row):
    if row.PetalLength < 2:
       return "Setosa"
   elif row.PetalLength > 5:
       return "Versicolor"
   else:
       return "Virginica"
# Out:
#   File "<ipython-input-79-417325ce638f>", line 4
#     elif row.PetalLength > 5:
#                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
c_hat != c.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-1760f7b6ba14> in <module>()
# ----> 1 c_hat != c.sum()
#
# NameError: name 'c_hat' is not defined

# %%
pdf.crosstab(a_at-c.rownaes = [Hypothesis Class] colnnames - ['True'])
# Out:
#   File "<ipython-input-47-9f4be39049ac>", line 1
#     pdf.crosstab(a_at-c.rownaes = [Hypothesis Class] colnnames - ['True'])
#                                                   ^
# SyntaxError: invalid syntax

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-9346242d1c07> in <module>()
# ----> 1 pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])
#
# NameError: name 'c_hat' is not defined

# %% [markdown]
# ## Part C | Classification Metrics

# %% [markdown]
# ### Accuracy

# %%
# TODO
(c_hat == c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8ea2a20ff40e> in <module>()
#       1 # TODO
# ----> 2 (c_hat == c)
#
# NameError: name 'c_hat' is not defined

# %% [markdown]
# ### Misclassification rate

# %%
# TODO

# %% [markdown]
# ## Part D | _k_-Nearest Neighbors (_k_-NN)

# %% [markdown]
# ### Feature matrix and response vector

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
columns_X = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
X = df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(X)

if row.PetalLength < 2:
       return "Setosa"
   elif row.PetalLength < 5:
       return "Versicolor"
   else:
       return "Virginica"
# Out:
#   File "<ipython-input-61-22315f2262c7>", line 8
#     elif row.PetalLength < 5:
#                              ^
# IndentationError: unindent does not match any outer indentation level

# %%
# TODO

# %%
c = df.Species

# %% [markdown]
# ### _k_-Nearest Neighbors

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = 1).\
    fit(X, c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-7e2da0f27ef4> in <module>()
# ----> 1 model = neighbors.KNeighborsClassifier(n_neighbors = 1).    fit(X, c)
#
# NameError: name 'X' is not defined

# %% [markdown]
# You can measure the precision of your prediction with `.score()`

# %%
model.score(X, c)

# %%
c_hat = model.predict(X)

# %%
(c_hat == c).mean()

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

# %% [markdown]
# ### Train/test sets

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html)

# %% [markdown]
# 50% of the dataset to train the model; the rest to test the model

# %%
train_df = df.sample(frac = .5, random_state = 0).sort_index()

# %%
train_df

# %%
test_df = df.drop(train_df.index)

# %% [markdown]
# ### Feature matrix `train_X` and response vector `train_c`

# %%
train_X = train_df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(train_X)
train_X = scaler.transform(train_X)

train_c = train_df.Species

# %% [markdown]
# ### Feature matrix `test_X` and response vector `test_c`

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
# TODO

# %%
k_cv = 5 # 5-fold CV
k_nn = range(1, train_df.shape[0] * (k_cv - 1) / k_cv) # k-NN

gs = model_selection.GridSearchCV(
    estimator = neighbors.KNeighborsClassifier(),
    param_grid = {'n_neighbors': k_nn, 'weights': ['uniform', 'distance']},
    cv = model_selection.KFold(n_splits = k_cv, shuffle = True, random_state = 0)
)

gs.fit(train_X, train_c)

# %%
gs.cv_results_

# %%
gs.cv_results_.keys()

# %%
gs.best_score_

# %%
gs.best_params_

# %%
gs.best_estimator_

# %%
gs.score(train_X, train_c)

# %%
gs.score(test_X, test_c)

# %% [markdown]
# ## Final model

# %%
# TODO
